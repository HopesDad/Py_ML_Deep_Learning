# %% [markdown]
# <a href="https://colab.research.google.com/github/youngsikwon/Py_ML_Deep_Learning/blob/master/Correlation_Between_Parental_Education_and_Child_Test_Scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# csv 파일 업로드 메소드 만들기.

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ee850a36-5c32-4d71-b148-98e785cd42cb" name="files[]" multiple disabled />
#      <output id="result-ee850a36-5c32-4d71-b148-98e785cd42cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv
# User uploaded file "StudentsPerformance.csv" with length 72036 bytes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')
sns.set(style="darkgrid", palette="bright", font_scale=1.5)

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.pairplot(df[['math score','reading score', 'writing score']], height=4)

# %% [markdown]
# ##Compute Average Score

# %%
def average_score(dt):
    return (dt['math score'] + dt['reading score'] + dt['writing score']) / 3

df['average score'] = df.apply(average_score, axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity  ... writing score average score
# 0  female        group B  ...            74     72.666667
# 1  female        group C  ...            88     82.333333
# 2  female        group B  ...            93     92.666667
# 3    male        group A  ...            44     49.333333
# 4    male        group C  ...            75     76.333333
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Lunch

# %%
sns.catplot(x='lunch', y='math score', hue='gender', kind='boxen', data=df, height=10, palette=sns.color_palette(['red', 'blue']))
plt.title('math')

sns.catplot(x='lunch', y='reading score', hue='gender', kind='boxen', data=df, height=10, palette=sns.color_palette(['red', 'blue']))
plt.title('reading')

sns.catplot(x='lunch', y='writing score', hue='gender', kind='boxen', data=df, height=10, palette=sns.color_palette(['red', 'blue']))
plt.title('writing')
# Out:
# Text(0.5, 1, 'writing')
